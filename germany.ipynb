# %% [markdown]
# # Übersicht Coronavirus 2020

# %%
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline
# Alternative plotting backend for interative data exploration
#%matplotlib widget

from coronavirus import overview, fetch_data_germany, germany_get_region

# %% [markdown]
# # Übersicht Deutschland

# %%
overview("Germany");

# %% [markdown]
# # Übersicht alle Bundesländer (optional)
# auskommentieren wenn benötigt

# %%
#germany = fetch_data_germany()

#laender = germany['Bundesland'].drop_duplicates().sort_values()

#for land in laender:
#    overview('Germany', region=land)

# %% [markdown]
# ## Übersicht Bayern

# %%
overview("Germany", region="Bayern");

# %% [markdown]
# ### Übersicht München Stadt

# %%
overview("Germany", subregion="SK München");
# Out:
# Can't plot doublingtime line for deaths in Germany-SK München due to too small numbers

# %% [markdown]
# ### Übersicht LK Garmisch

# %%
overview("Germany", subregion="LK Garmisch-Partenkirchen");
# Out:
# Can't plot doublingtime line for deaths in Germany-LK Garmisch-Partenkirchen due to too small numbers
# Can't plot doublingtime line for cases in Germany-LK Garmisch-Partenkirchen due to too small numbers

# %% [markdown]
# ## Übersicht Thüringen

# %%
overview("Germany", region="Thüringen");
# Out:
# Can't plot doublingtime line for deaths in Germany-Thüringen due to too small numbers

# %% [markdown]
# ### Übersicht Meiningen

# %%
overview("Germany", subregion="LK Schmalkalden-Meiningen");
# Out:
# Can't plot doublingtime line for deaths in Germany-LK Schmalkalden-Meiningen due to too small numbers
# Can't plot doublingtime line for cases in Germany-LK Schmalkalden-Meiningen due to too small numbers
